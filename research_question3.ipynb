# %%
import pandas as pd
import numpy as np
from helpers import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.ticker import MaxNLocator
from geopy.geocoders import Nominatim
import folium
from folium.plugins import HeatMap
from IPython.display import display
from geopy.distance import geodesic
import math
from statsmodels.stats import diagnostic
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
beers = pd.read_csv("dataset/FilteredData/beers.csv")
breweries = pd.read_csv("dataset/FilteredData/breweries.csv")
ratings = pd.read_csv("dataset/FilteredData/ratings.csv", dtype = {'user_id': str})
users = pd.read_csv("dataset/FilteredData/users.csv", dtype = {'user_id': str})

# %%
all_years_list = sorted(ratings['year'].unique())
style_popularities_by_year = pd.DataFrame()
for year in all_years_list:
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = False)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_most_popular = location_style_groupedby_loc['popularity_percentage'].idxmax()
    most_popular_styles_by_location = location_style.loc[idx_most_popular]
    most_popular_styles_by_location = most_popular_styles_by_location[['location', 'style']]
    most_popular_styles_by_location.set_index('location', inplace = True)
    most_popular_styles_by_location = most_popular_styles_by_location.rename(columns = {'style': str(year)})
    style_popularities_by_year = pd.concat([style_popularities_by_year, most_popular_styles_by_location], axis = 1)

style_popularities_by_year
# Out:
#                                               2006                  2007  \
# location
# Australia                               Pale Lager            Pale Lager
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                  Fruit Beer             Cream Ale
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  American Strong Ale
# United States, Washington     India Pale Ale (IPA)             Amber Ale
# United States, West Virginia  India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wisconsin            Imperial Stout        Imperial Stout
# United States, Wyoming                      Porter     American Pale Ale
#
#                                               2008                  2009  \
# location
# Australia                               Pale Lager            Pale Lager
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                  Scotch Ale            Fruit Beer
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)             Black IPA
# United States, Washington     India Pale Ale (IPA)          Imperial IPA
# United States, West Virginia             Amber Ale                Porter
# United States, Wisconsin                    Porter                Porter
# United States, Wyoming                  Pale Lager  American Strong Ale
#
#                                               2010                  2011  \
# location
# Australia                               Pale Lager            Pale Lager
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                   Cream Ale            Scotch Ale
# Croatia                                   Pilsener            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  Spice/Herb/Vegetable
# United States, Washington     American Strong Ale   American Strong Ale
# United States, West Virginia             Amber Ale  Spice/Herb/Vegetable
# United States, Wisconsin                Fruit Beer             Amber Ale
# United States, Wyoming                  Pale Lager     American Pale Ale
#
#                                               2012                  2013  \
# location
# Australia                        American Pale Ale     American Pale Ale
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                        Spice/Herb/Vegetable                Saison
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       Spice/Herb/Vegetable  Spice/Herb/Vegetable
# United States, Washington                   Saison                Saison
# United States, West Virginia  Spice/Herb/Vegetable  Spice/Herb/Vegetable
# United States, Wisconsin               Barley Wine        Imperial Stout
# United States, Wyoming              Imperial Stout                Porter
#
#                                               2014                  2015  \
# location
# Australia                        American Pale Ale     American Pale Ale
# Belgium                                Belgian Ale           Belgian Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                  Fruit Beer                Saison
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       Spice/Herb/Vegetable  Spice/Herb/Vegetable
# United States, Washington                   Saison           Barley Wine
# United States, West Virginia  Spice/Herb/Vegetable  Spice/Herb/Vegetable
# United States, Wisconsin            Imperial Stout        Imperial Stout
# United States, Wyoming           American Pale Ale            Fruit Beer
#
#                                               2016                  2017
# location
# Australia                        American Pale Ale     American Pale Ale
# Belgium                                Belgian Ale           Belgian Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                      Saison         Sour/Wild Ale
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia                Sweet Stout          Imperial IPA
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia              Pilsener     German Hefeweizen
# United States, Wisconsin            Imperial Stout        Imperial Stout
# United States, Wyoming                  Pale Lager         Sour/Wild Ale
#
# [71 rows x 12 columns]

# %%
all_years_list = sorted(ratings['year'].unique())
style_ratings_by_year = pd.DataFrame()
for year in all_years_list:
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = True)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_highest_rated = location_style_groupedby_loc['z_score'].idxmax()
    highest_rated_styles_by_location = location_style.loc[idx_highest_rated]
    highest_rated_styles_by_location = highest_rated_styles_by_location[['location', 'style']]
    highest_rated_styles_by_location.set_index('location', inplace = True)
    highest_rated_styles_by_location = highest_rated_styles_by_location.rename(columns = {'style': str(year)})
    style_ratings_by_year = pd.concat([style_ratings_by_year, highest_rated_styles_by_location], axis = 1)

style_ratings_by_year
# Out:
#                                             2006                   2007  \
# location
# Australia                          Abt/Quadrupel          Abt/Quadrupel
# Belgium                            Abt/Quadrupel          Abt/Quadrupel
# Brazil                         German Hefeweizen          Abt/Quadrupel
# Canada                             Abt/Quadrupel          Abt/Quadrupel
# Croatia                       Belgian Strong Ale                 Porter
# ...                                          ...                    ...
# United States, Virginia            Abt/Quadrupel          Abt/Quadrupel
# United States, Washington          Abt/Quadrupel          Abt/Quadrupel
# United States, West Virginia          Doppelbock         Imperial Stout
# United States, Wisconsin           Sour/Wild Ale  Lambic Style - Gueuze
# United States, Wyoming              Imperial IPA         Imperial Stout
#
#                                                2008                   2009  \
# location
# Australia                             Abt/Quadrupel          Abt/Quadrupel
# Belgium                               Abt/Quadrupel          Abt/Quadrupel
# Brazil                                Abt/Quadrupel     Belgian Strong Ale
# Canada                                Abt/Quadrupel          Abt/Quadrupel
# Croatia                               Abt/Quadrupel         Imperial Stout
# ...                                             ...                    ...
# United States, Virginia              Sour Red/Brown  Lambic Style - Gueuze
# United States, Washington     Lambic Style - Gueuze         Sour Red/Brown
# United States, West Virginia          Abt/Quadrupel          Abt/Quadrupel
# United States, Wisconsin      Lambic Style - Gueuze         Imperial Stout
# United States, Wyoming                        Stout          Sour/Wild Ale
#
#                                                   2010                   2011  \
# location
# Australia                                Abt/Quadrupel          Abt/Quadrupel
# Belgium                                  Abt/Quadrupel  Lambic Style - Gueuze
# Brazil                                  Imperial Stout   Lambic Style - Fruit
# Canada                                   Abt/Quadrupel          Abt/Quadrupel
# Croatia                                 Imperial Stout         Imperial Stout
# ...                                                ...                    ...
# United States, Virginia                  Sour/Wild Ale  Lambic Style - Gueuze
# United States, Washington     Lambic Style - Unblended  Lambic Style - Gueuze
# United States, West Virginia             Abt/Quadrupel          Abt/Quadrupel
# United States, Wisconsin         Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Wyoming                  Imperial Stout           Imperial IPA
#
#                                                   2012                   2013  \
# location
# Australia                                Abt/Quadrupel                Eisbock
# Belgium                                  Abt/Quadrupel         Imperial Stout
# Brazil                                   Abt/Quadrupel          Abt/Quadrupel
# Canada                           Lambic Style - Gueuze          Abt/Quadrupel
# Croatia                                 Imperial Stout         Imperial Stout
# ...                                                ...                    ...
# United States, Virginia       Lambic Style - Unblended  Lambic Style - Gueuze
# United States, Washington        Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, West Virginia             Abt/Quadrupel          Abt/Quadrupel
# United States, Wisconsin         Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Wyoming                  Imperial Stout         Imperial Stout
#
#                                                2014                   2015  \
# location
# Australia                             Abt/Quadrupel  Lambic Style - Gueuze
# Belgium                        American Strong Ale          Imperial Stout
# Brazil                                Abt/Quadrupel          Abt/Quadrupel
# Canada                                Abt/Quadrupel  Lambic Style - Gueuze
# Croatia                              Imperial Stout         Imperial Stout
# ...                                             ...                    ...
# United States, Virginia       Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Washington     Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, West Virginia         Imperial Stout   Lambic Style - Fruit
# United States, Wisconsin             Imperial Stout  Lambic Style - Gueuze
# United States, Wyoming               Sour Red/Brown         Imperial Stout
#
#                                                   2016                   2017
# location
# Australia                               Imperial Stout          Abt/Quadrupel
# Belgium                                 Imperial Stout         Imperial Stout
# Brazil                                   Abt/Quadrupel           Abbey Tripel
# Canada                           Lambic Style - Gueuze  Lambic Style - Gueuze
# Croatia                                  Abt/Quadrupel   Lambic Style - Fruit
# ...                                                ...                    ...
# United States, Virginia          Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Washington        Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, West Virginia            Imperial Stout          Abt/Quadrupel
# United States, Wisconsin      Lambic Style - Unblended  Lambic Style - Gueuze
# United States, Wyoming                  Imperial Stout         Imperial Stout
#
# [71 rows x 12 columns]

# %%
all_years_list = sorted(ratings['year'].unique())
bc_popularities_by_year = pd.DataFrame()
for year in all_years_list:
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = False)
    location_bc_gb_loc = location_bc.groupby('location')
    idx_most_popular = location_bc_gb_loc['popularity_percentage'].idxmax()
    most_popular_bc_by_location = location_bc.loc[idx_most_popular]
    most_popular_bc_by_location = most_popular_bc_by_location[['location', 'brewery_location']]
    most_popular_bc_by_location.set_index('location', inplace = True)
    most_popular_bc_by_location = most_popular_bc_by_location.rename(columns = {'brewery_location': str(year)})
    bc_popularities_by_year = pd.concat([bc_popularities_by_year, most_popular_bc_by_location], axis = 1)
    
bc_popularities_by_year
# Out:
#                                                      2006  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                             Brazil
# Canada                                             Canada
# Croatia                                           Austria
# ...                                                   ...
# United States, Virginia           United States, Virginia
# United States, Washington       United States, Washington
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming            United States, Colorado
#
#                                                      2007  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                            Belgium
# Canada                                             Canada
# Croatia                                           Croatia
# ...                                                   ...
# United States, Virginia           United States, Virginia
# United States, Washington       United States, California
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming            United States, Colorado
#
#                                                    2008  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia         United States, New York
# United States, Washington     United States, California
# United States, West Virginia    United States, New York
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Missouri
#
#                                                    2009  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                  Czech Republic
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia    United States, New York
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
#                                                    2010  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia    United States, New York
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
#                                                      2011  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                             Brazil
# Canada                                             Canada
# Croatia                                           Germany
# ...                                                   ...
# United States, Virginia           United States, Virginia
# United States, Washington           United States, Oregon
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming          United States, California
#
#                                                      2012  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                             Brazil
# Canada                                             Canada
# Croatia                                           Germany
# ...                                                   ...
# United States, Virginia           United States, Virginia
# United States, Washington       United States, Washington
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming          United States, California
#
#                                                       2013  \
# location
# Australia                                        Australia
# Belgium                                            Belgium
# Brazil                                              Brazil
# Canada                                              Canada
# Croatia                                            Germany
# ...                                                    ...
# United States, Virginia            United States, Virginia
# United States, Washington        United States, Washington
# United States, West Virginia  United States, Massachusetts
# United States, Wisconsin          United States, Wisconsin
# United States, Wyoming           United States, California
#
#                                                      2014  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                             Brazil
# Canada                                             Canada
# Croatia                                           Germany
# ...                                                   ...
# United States, Virginia           United States, Virginia
# United States, Washington       United States, Washington
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming          United States, California
#
#                                                    2015  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia        United States, Ohio
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
#                                                    2016  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Croatia
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia        United States, Ohio
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
#                                                    2017
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Croatia
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia        United States, Ohio
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
# [71 rows x 12 columns]

# %%
all_years_list = sorted(ratings['year'].unique())
bc_ratings_by_year = pd.DataFrame()
for year in all_years_list:
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = True)
    location_bc_gb_loc = location_bc.groupby('location')
    idx_highest_rated = location_bc_gb_loc['z_score'].idxmax()
    highest_rated_bc_by_location = location_bc.loc[idx_highest_rated]
    highest_rated_bc_by_location = highest_rated_bc_by_location[['location', 'brewery_location']]
    highest_rated_bc_by_location.set_index('location', inplace=True)
    highest_rated_bc_by_location = highest_rated_bc_by_location.rename(columns={'brewery_location': str(year)})
    bc_ratings_by_year = pd.concat([bc_ratings_by_year, highest_rated_bc_by_location], axis=1)
    
bc_ratings_by_year
# Out:
#                                                     2006  \
# location
# Australia                      United States, California
# Belgium                        United States, California
# Brazil                                           Germany
# Canada                             United States, Alaska
# Croatia                                          Belgium
# ...                                                  ...
# United States, Virginia       United States, Connecticut
# United States, Washington     United States, Connecticut
# United States, West Virginia         United States, Ohio
# United States, Wisconsin       United States, New Jersey
# United States, Wyoming                           Belgium
#
#                                                     2007  \
# location
# Australia                        United States, Colorado
# Belgium                        United States, California
# Brazil                                            Canada
# Canada                                            Norway
# Croatia                                          Belgium
# ...                                                  ...
# United States, Virginia       United States, Connecticut
# United States, Washington                         Norway
# United States, West Virginia                     Belgium
# United States, Wisconsin                          Norway
# United States, Wyoming         United States, California
#
#                                                    2008  \
# location
# Australia                         United States, Oregon
# Belgium                         United States, Michigan
# Brazil                        United States, California
points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    style_popularity_points_dict = {key: 0 for key in ratings['style'].unique().tolist()}
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = False)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_10_most_popular = location_style_groupedby_loc['popularity_percentage'].nlargest(10).index.get_level_values(1)
    most_popular_styles_by_location = location_style.loc[idx_10_most_popular]
    
    point_idx = 0
    prev_location = most_popular_styles_by_location.iloc[0]['location']
    for index, row in most_popular_styles_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        style_popularity_points_dict[row['style']] += points[point_idx]
        point_idx += 1
    global_style_popularity_points_by_year[str(year)] = style_popularity_points_dict

global_style_popularities_by_year = global_style_popularity_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T

global_style_popularities_by_year.columns = ['1st Most Popular', '2nd Most Popular', '3rd Most Popular', '4th Most Popular', '5th Most Popular', '6th Most Popular', '7th Most Popular', '8th Most Popular', '9th Most Popular', '10th Most Popular']
global_style_popularities_by_year.index.name = 'Year'
global_style_popularities_by_year
# Out:
#           1st Most Popular      2nd Most Popular      3rd Most Popular  \
# Year
# 2006  India Pale Ale (IPA)        Imperial Stout           Barley Wine
# 2007        Imperial Stout  American Strong Ale             Pale Lager
# 2008            Pale Lager          Imperial IPA           Sweet Stout
# 2009  Spice/Herb/Vegetable              Pilsener  India Pale Ale (IPA)
# 2010            Pale Lager        Imperial Stout  Spice/Herb/Vegetable
# 2011  Spice/Herb/Vegetable        Imperial Stout            Pale Lager
# 2012  Spice/Herb/Vegetable            Pale Lager         Sour/Wild Ale
# 2013           Sweet Stout        Imperial Stout             Brown Ale
# 2014        Imperial Stout     American Pale Ale          Imperial IPA
# 2015        Imperial Stout                Saison     American Pale Ale
# 2016        Imperial Stout  India Pale Ale (IPA)              Pilsener
# 2017  India Pale Ale (IPA)        Imperial Stout          Imperial IPA
#
#           4th Most Popular    5th Most Popular      6th Most Popular  \
# Year
# 2006            Pale Lager  Belgian Strong Ale  Spice/Herb/Vegetable
# 2007              Pilsener           Amber Ale  India Pale Ale (IPA)
# 2008        Imperial Stout  Belgian Strong Ale  India Pale Ale (IPA)
# 2009                Saison             Witbier  American Strong Ale
# 2010  India Pale Ale (IPA)        Imperial IPA  American Strong Ale
# 2011                Saison            Pilsener          Imperial IPA
# 2012           Barley Wine  Amber Lager/Vienna          Imperial IPA
# 2013  Spice/Herb/Vegetable           Wheat Ale                Saison
# 2014  India Pale Ale (IPA)           Wheat Ale  Spice/Herb/Vegetable
# 2015          Imperial IPA           Brown Ale  India Pale Ale (IPA)
# 2016     American Pale Ale               Stout            Fruit Beer
# 2017         Sour/Wild Ale         Sweet Stout              Pilsener
#
#           7th Most Popular   8th Most Popular      9th Most Popular  \
# Year
# 2006              Pilsener             Porter             Brown Ale
# 2007          Imperial IPA             Saison    Amber Lager/Vienna
# 2008                Porter             Saison              Pilsener
# 2009          Imperial IPA        Barley Wine                Porter
# 2010    Belgian Strong Ale             Porter         Sour/Wild Ale
# 2011             Wheat Ale      Sour/Wild Ale  India Pale Ale (IPA)
# 2012            Scotch Ale          Wheat Ale        Imperial Stout
# 2013            Pale Lager  American Pale Ale       Berliner Weisse
# 2014            Pale Lager             Saison             Brown Ale
# 2015  Spice/Herb/Vegetable        Sweet Stout            Pale Lager
# 2016          Imperial IPA             Saison                Porter
# 2017     American Pale Ale    Berliner Weisse                 Stout
#
#       10th Most Popular
# Year
# 2006        Belgian Ale
# 2007  American Pale Ale
# 2008        Barley Wine
# 2009         Pale Lager
# 2010        Barley Wine
# 2011          Amber Ale
# 2012             Saison
# 2013       Imperial IPA
# 2014         Fruit Beer
# 2015        Barley Wine
# 2016      Sour/Wild Ale
# 2017         Pale Lager

# %%
all_years_list = sorted(ratings['year'].unique())
global_style_rating_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    style_rating_points_dict = {key: 0 for key in ratings['style'].unique().tolist()}
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = True)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_10_highest_rated = location_style_groupedby_loc['z_score'].nlargest(10).index.get_level_values(1)
    highest_rated_styles_by_location = location_style.loc[idx_10_highest_rated]
    
    point_idx = 0
    prev_location = highest_rated_styles_by_location.iloc[0]['location']
    for index, row in highest_rated_styles_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        style_rating_points_dict[row['style']] += points[point_idx]
        point_idx += 1
    global_style_rating_points_by_year[str(year)] = style_rating_points_dict

global_style_highest_rated_by_year = global_style_rating_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T

global_style_highest_rated_by_year.columns = ['1st Highest Rated', '2nd Highest Rated', '3rd Highest Rated', '4th Highest Rated', '5th Highest Rated', '6th Highest Rated', '7th Highest Rated', '8th Highest Rated', '9th Highest Rated', '10th Highest Rated']
global_style_highest_rated_by_year.index.name = 'Year'
global_style_highest_rated_by_year
# Out:
#      1st Highest Rated      2nd Highest Rated      3rd Highest Rated  \
# Year
# 2006    Imperial Stout          Abt/Quadrupel           Imperial IPA
# 2007     Abt/Quadrupel         Imperial Stout           Imperial IPA
# 2008     Abt/Quadrupel         Imperial Stout           Imperial IPA
# 2009    Imperial Stout          Abt/Quadrupel         Sour Red/Brown
# 2010    Imperial Stout          Abt/Quadrupel  Lambic Style - Gueuze
# 2011    Imperial Stout          Abt/Quadrupel  Lambic Style - Gueuze
# 2012    Imperial Stout          Abt/Quadrupel  Lambic Style - Gueuze
# 2013    Imperial Stout  Lambic Style - Gueuze          Abt/Quadrupel
# 2014    Imperial Stout  Lambic Style - Gueuze          Abt/Quadrupel
# 2015    Imperial Stout  Lambic Style - Gueuze          Abt/Quadrupel
# 2016    Imperial Stout  Lambic Style - Gueuze          Abt/Quadrupel
# 2017    Imperial Stout  Lambic Style - Gueuze          Abt/Quadrupel
#
#           4th Highest Rated      5th Highest Rated         6th Highest Rated  \
# Year
# 2006     Belgian Strong Ale          Sour/Wild Ale                   Eisbock
# 2007          Sour/Wild Ale     Belgian Strong Ale            Sour Red/Brown
# 2008  Lambic Style - Gueuze          Sour/Wild Ale            Sour Red/Brown
# 2009           Imperial IPA  Lambic Style - Gueuze             Sour/Wild Ale
# 2010          Sour/Wild Ale         Sour Red/Brown              Imperial IPA
# 2011           Imperial IPA          Sour/Wild Ale  Lambic Style - Unblended
# 2012           Imperial IPA          Sour/Wild Ale            Sour Red/Brown
# 2013           Imperial IPA          Sour/Wild Ale      Lambic Style - Fruit
# 2014          Sour/Wild Ale   Lambic Style - Fruit              Imperial IPA
# 2015   Lambic Style - Fruit           Imperial IPA             Sour/Wild Ale
# 2016   Lambic Style - Fruit           Imperial IPA  Lambic Style - Unblended
# 2017           Imperial IPA   Lambic Style - Fruit            Sour Red/Brown
#
#              7th Highest Rated      8th Highest Rated  \
# Year
# 2006     Lambic Style - Gueuze         Sour Red/Brown
# 2007             Baltic Porter  Lambic Style - Gueuze
# 2008        Belgian Strong Ale                Eisbock
# 2009               Barley Wine     Belgian Strong Ale
# 2010  Lambic Style - Unblended            Weizen Bock
# 2011      Lambic Style - Fruit         Sour Red/Brown
# 2012               Barley Wine                Eisbock
# 2013                   Eisbock         Sour Red/Brown
# 2014            Sour Red/Brown                Eisbock
# 2015  Lambic Style - Unblended            Barley Wine
# 2016            Sour Red/Brown          Sour/Wild Ale
# 2017             Sour/Wild Ale            Barley Wine
#
#              9th Highest Rated        10th Highest Rated
# Year
# 2006             Baltic Porter               Barley Wine
# 2007               Barley Wine      American Strong Ale
# 2008               Barley Wine             Baltic Porter
# 2009                   Eisbock      American Strong Ale
# 2010      American Strong Ale         Belgian Strong Ale
# 2011                   Old Ale               Barley Wine
# 2012      Lambic Style - Fruit  Lambic Style - Unblended
# 2013  Lambic Style - Unblended                   Old Ale
# 2014  Lambic Style - Unblended               Barley Wine
# 2015            Sour Red/Brown                   Eisbock
# 2016               Barley Wine                   Old Ale
# 2017      American Strong Ale                    Old Ale

# %%
all_years_list = sorted(ratings['year'].unique())
global_brewery_popularity_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    brewery_popularity_points_dict = {key: 0 for key in breweries['location'].unique().tolist()}
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = False)
    location_bc_groupedby_loc = location_bc.groupby('location')
    idx_10_most_popular = location_bc_groupedby_loc['popularity_percentage'].nlargest(10).index.get_level_values(1)
    most_popular_breweries_by_location = location_bc.loc[idx_10_most_popular]
    
    point_idx = 0
    prev_location = most_popular_breweries_by_location.iloc[0]['location']
    for index, row in most_popular_breweries_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        brewery_popularity_points_dict[row['brewery_location']] += points[point_idx]
        point_idx += 1
    global_brewery_popularity_points_by_year[str(year)] = brewery_popularity_points_dict

global_brewery_popularities_by_year = global_brewery_popularity_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T

global_brewery_popularities_by_year.columns = ['1st Most Popular', '2nd Most Popular', '3rd Most Popular', '4th Most Popular', '5th Most Popular', '6th Most Popular', '7th Most Popular', '8th Most Popular', '9th Most Popular', '10th Most Popular']
global_brewery_popularities_by_year.index.name = 'Year'
global_brewery_popularities_by_year
# Out:
#                   1st Most Popular              2nd Most Popular  \
# Year
# 2006                       Belgium       United States, New York
# 2007       United States, Maryland       United States, Missouri
# 2008       United States, New York       United States, Missouri
# 2009       United States, New York       United States, Colorado
# 2010       United States, New York       United States, Colorado
# 2011       United States, New York  United States, Massachusetts
# 2012                       Belgium       United States, New York
# 2013  United States, Massachusetts                       Belgium
# 2014                       Belgium                        Mexico
# 2015                        Mexico       United States, Colorado
# 2016                       Belgium  United States, Massachusetts
# 2017                        Mexico                       England
#
#                   3rd Most Popular              4th Most Popular  \
# Year
# 2006     United States, California                       Germany
# 2007  United States, Massachusetts       United States, Colorado
# 2008  United States, Massachusetts       United States, Colorado
# 2009       United States, Missouri                       Germany
# 2010  United States, Massachusetts         United States, Oregon
# 2011       United States, Colorado       United States, Missouri
# 2012       United States, Colorado                        Mexico
# 2013       United States, New York                       Germany
# 2014       United States, Colorado                         Japan
# 2015                       Belgium  United States, Massachusetts
# 2016                        Mexico       United States, Colorado
# 2017     United States, California                       Belgium
#
#                   5th Most Popular              6th Most Popular  \
# Year
# 2006       United States, Michigan   United States, Pennsylvania
# 2007       United States, New York         United States, Oregon
# 2008                       Belgium     United States, California
# 2009  United States, Massachusetts        United States, Georgia
# 2010        United States, Georgia                       Germany
# 2011   United States, Pennsylvania                        Mexico
# 2012                       Germany       United States, Missouri
# 2013       United States, Missouri                        Mexico
# 2014                       Jamaica  United States, Massachusetts
# 2015                       Jamaica        United States, Vermont
# 2016     United States, California                       England
# 2017  United States, Massachusetts                         Japan
#
#                7th Most Popular              8th Most Popular  \
# Year
# 2006    United States, Colorado       United States, Delaware
# 2007     United States, Georgia       United States, Michigan
# 2008      United States, Oregon                       England
# 2009      United States, Oregon   United States, Pennsylvania
# 2010                    England                        Mexico
# 2011     United States, Georgia       United States, Illinois
# 2012      United States, Oregon  United States, Massachusetts
# 2013  United States, California       United States, Colorado
# 2014      United States, Oregon                       Germany
# 2015                    England         United States, Oregon
# 2016     United States, Vermont                Czech Republic
# 2017     United States, Vermont                       Austria
#
#                  9th Most Popular             10th Most Popular
# Year
# 2006     United States, Wisconsin  United States, Massachusetts
# 2007    United States, California                       England
# 2008      United States, Maryland   United States, Pennsylvania
# 2009    United States, California                       Belgium
# 2010      United States, Missouri       United States, Michigan
# 2011    United States, California                       England
# 2012       United States, Georgia                   Switzerland
# 2013       United States, Georgia   United States, Pennsylvania
# 2014    United States, California   United States, Pennsylvania
# 2015    United States, California     United States, Washington
# 2016  United States, Pennsylvania         United States, Oregon
# 2017               Czech Republic                       Denmark

# %%
all_years_list = sorted(ratings['year'].unique())
global_brewery_rating_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    brewery_rating_points_dict = {key: 0 for key in breweries['location'].unique().tolist()}
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = True)
    location_bc_groupedby_loc = location_bc.groupby('location')
    idx_10_highest_rated = location_bc_groupedby_loc['z_score'].nlargest(10).index.get_level_values(1)
    highest_rated_breweries_by_location = location_bc.loc[idx_10_highest_rated]
    
    point_idx = 0
    prev_location = highest_rated_breweries_by_location.iloc[0]['location']
    for index, row in highest_rated_breweries_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        brewery_rating_points_dict[row['brewery_location']] += points[point_idx]
        point_idx += 1
    global_brewery_rating_points_by_year[str(year)] = brewery_rating_points_dict

global_brewery_highest_rated_by_year = global_brewery_rating_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).